# %%
import pandas as pd  # Đảm bảo import pandas nếu chưa có

result = './additionalBaselineNoise.csv'

# KNN
# LUNAR
# NeuTraLAD
# LOF
# AutoEncoder
# CBLOF
# HBOS
# DASVDD
# PCA
# AE1SVM
# DevNet
# DeepSVDD
# IForest
# OCSVM
# LODA
# MO_GAAL
# SUOD
# DIF
# ALAD
# COPOD
# ECOD
# Load the CSV file
df = pd.read_csv(result)
# df.sort_values(by=['Model'], ascending=[True], inplace = True )

# Filter rows where 'Dataset' is empty string
# df = df[df['Model'] == 'ECOD'] 

#  	data_ToNIoT.csv , data_N_BaIoT.csv, data_CICIoT2023.csv, data_BoTIoT.csv
# df = df[df['Dataset'] == 'data_ToNIoT.csv']


# Further filter where 'noise_percentage' is empty string
# df = df[df['noise_percentage'] == 0] 

# Lưu df2 vào cùng thư mục với tên file mới, ví dụ: 'filtered_df2.csv'
# Sử dụng index=False để không lưu index làm cột
df.to_csv('./filtered_df2.csv', index=False)

# Optional: In ra thông báo để xác nhận
print(f"File đã được lưu thành công tại: ./filtered_df2.csv")
print(f"Số lượng hàng trong df2: {len(df)}")
# Out:
# File đã được lưu thành công tại: ./filtered_df2.csv
# Số lượng hàng trong df2: 64
